# %% [markdown]
# # variables in python
# 1. variables is memory allocation to value
# 2. examples are name="charan", age=16, salary=40000,18
#
# ## key points
# 1. varibles do not start with digit
# 2. varibles does not allowed special characters
# 3. do not use keyboards as a varibles

# %%
name="shiva"
age=20
salary=60000
print(name)
print(age)
print(salary)

# %%
1name="chi
